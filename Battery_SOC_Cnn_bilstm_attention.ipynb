# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVR
from mat2json import loadMat
from util import getBatteryCapacity, getChargingValues, getDischargingValues, getDataframe, series_to_supervised, rollingAverage
from keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt #import plot
from mat2json import loadMat
from util import getBatteryCapacity, getChargingValues, getDischargingValues, getDataframe, series_to_supervised, rollingAverage

# %%
import keras.backend as K
import numpy as np


def get_activations(model, inputs, print_shape_only=False, layer_name=None):
    # From: https://github.com/philipperemy/keras-visualize-activations
    activations = []
    inp = model.input
    if layer_name is None:
        outputs = [layer.output for layer in model.layers]
    else:
        outputs = [layer.output for layer in model.layers if layer.name == layer_name]  # all layer outputs
    funcs = [K.function([inp] + [K.learning_phase()], [out]) for out in outputs]  # evaluation functions
    layer_outputs = [func([inputs, 1.])[0] for func in funcs]
    for layer_activations in layer_outputs:
        activations.append(layer_activations)
        if print_shape_only:
            print(layer_activations.shape)
        else:
            print(layer_activations.shape)
            print(layer_activations)
    return activations


def get_data(n, input_dim, attention_column=1):
    """
    Data generation. x is purely random except that it's first value equals the target y.
    In practice, the network should learn that the target = x[attention_column].
    Therefore, most of its attention should be focused on the value addressed by attention_column.
    :param n: the number of samples to retrieve.
    :param input_dim: the number of dimensions of each element in the series.
    :param attention_column: the column linked to the target. Everything else is purely random.
    :return: x: model inputs, y: model targets
    """
    x = np.random.standard_normal(size=(n, input_dim))
    y = np.random.randint(low=0, high=2, size=(n, 1))
    x[:, attention_column] = y[:, 0]
    return x, y


def get_data_recurrent(n, time_steps, input_dim, attention_column=10):
    """
    Data generation. x is purely random except that it's first value equals the target y.
    In practice, the network    should learn that the target = x[attention_column].
    Therefore, most of its attention should be focused on the value addressed by attention_column.
    :param n: the number of samples to retrieve.
    :param time_steps: the number of time steps of your series.
    :param input_dim: the number of dimensions of each element in the series.
    :param attention_column: the column linked to the target. Everything else is purely random.
    :return: x: model inputs, y: model targets
    """
    x = np.random.standard_normal(size=(n, time_steps, input_dim))
    y = np.random.randint(low=0, high=2, size=(n, 1))
    x[:, attention_column, :] = np.tile(y[:], (1, input_dim))
    return x, y


def get_data_recurrent2(n, time_steps, input_dim, attention_dim=5):
    x = np.random.standard_normal(size=(n, time_steps, input_dim))
    y = np.random.randint(low=0, high=2, size=(n, 1))
    x[:,:,attention_dim] =  np.tile(y[:], (1, time_steps))


    return x,y

# %%
from keras.layers import Input, Dense, LSTM, merge ,Conv1D,Dropout,Bidirectional,Multiply
from keras.models import Model

#from attention_utils import get_activations
from keras.layers import merge
from keras.layers import Multiply
from keras.layers.core import *
from keras.layers.recurrent import LSTM
from keras.models import *

import  pandas as pd
import  numpy as np

SINGLE_ATTENTION_VECTOR = False
def attention_3d_block(inputs):
    # inputs.shape = (batch_size, time_steps, input_dim)
    input_dim = int(inputs.shape[2])
    a = inputs
    a = Dense(input_dim, activation='softmax')(a)
    if SINGLE_ATTENTION_VECTOR:
        a = Lambda(lambda x: K.mean(x, axis=1), name='dim_reduction')(a)
        a = RepeatVector(input_dim)(a)
    a_probs = Permute((1, 2), name='attention_vec')(a)

    #output_attention_mul = merge([inputs, a_probs], name='attention_mul', mode='mul')
    output_attention_mul = Multiply()([inputs, a_probs])
    return output_attention_mul

# Another way of writing the attention mechanism is suitable for the use of the above error source:https://blog.csdn.net/uhauha2929/article/details/80733255
def attention_3d_block2(inputs, single_attention_vector=False):
    # If the upper layer is LSTM, you need return_sequences=True
    # inputs.shape = (batch_size, time_steps, input_dim)
    time_steps = K.int_shape(inputs)[1]
    input_dim = K.int_shape(inputs)[2]
    a = Permute((2, 1))(inputs)
    a = Dense(time_steps, activation='softmax')(a)
    if single_attention_vector:
        a = Lambda(lambda x: K.mean(x, axis=1))(a)
        a = RepeatVector(input_dim)(a)

    a_probs = Permute((2, 1))(a)
    # Multiplied by the attention weight, but there is no summation, it seems to have little effect
    # If you classify tasks, you can do Flatten expansion
    # element-wise
    output_attention_mul = Multiply()([inputs, a_probs])
    return output_attention_mul



def create_dataset(dataset, look_back):
    '''
    Processing the data
    '''
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back),:]
        dataX.append(a)
        dataY.append(dataset[i + look_back,:])
    TrainX = np.array(dataX)
    Train_Y = np.array(dataY)

    return TrainX, Train_Y

# Multidimensional normalization returns data and maximum and minimum values
def NormalizeMult(data):
    #normalize used for denormalization
    data = np.array(data)
    normalize = np.arange(2*data.shape[1],dtype='float64')

    normalize = normalize.reshape(data.shape[1],2)
    print(normalize.shape)
    for i in range(0,data.shape[1]):
        #Column i
        list = data[:,i]
        listlow,listhigh =  np.percentile(list, [0, 100])
        # print(i)
        normalize[i,0] = listlow
        normalize[i,1] = listhigh
        delta = listhigh - listlow
        if delta != 0:
            #Row j
            for j in range(0,data.shape[0]):
                data[j,i]  =  (data[j,i] - listlow)/delta
    #np.save("./normalize.npy",normalize)
    return  data,normalize

# Multidimensional denormalization
def FNormalizeMult(data,normalize):
    data = np.array(data)
    for i in  range(0,data.shape[1]):
        listlow =  normalize[i,0]
        listhigh = normalize[i,1]
        delta = listhigh - listlow
        if delta != 0:
            #Row j
            for j in range(0,data.shape[0]):
                data[j,i]  =  data[j,i]*delta + listlow

    return data


def attention_model():
    inputs = Input(shape=(TIME_STEPS, INPUT_DIMS))

    x = Conv1D(filters = 64, kernel_size = 1, activation = 'relu')(inputs)  #, padding = 'same'
    x = Dropout(0.3)(x)

    #lstm_out = Bidirectional(LSTM(lstm_units, activation='relu'), name='bilstm')(x)
    #For GPU you can use CuDNNLSTM
    lstm_out = Bidirectional(LSTM(lstm_units, return_sequences=True))(x)
    lstm_out = Dropout(0.3)(lstm_out)
    attention_mul = attention_3d_block(lstm_out)
    attention_mul = Flatten()(attention_mul)

    #output = Dense(1, activation='sigmoid')(attention_mul)
    output = Dense(1, activation='linear')(attention_mul)
    model = Model(inputs=[inputs], outputs=output)
    return model

# %%
B0005 = loadMat('B0005.mat')
B0006 = loadMat('B0006.mat')
B0007 = loadMat('B0007.mat')

# %%
dfB0005 = getDataframe(B0005)

# %%
sns.residplot(dfB0005['cycle'], dfB0005['capacity'])
# Out:
# /home/aimran/.local/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='cycle', ylabel='capacity'>

# %%
dfB0006 = getDataframe(B0006)
dfB0007 = getDataframe(B0007)

dfB0006

#X = dfB0007['cycle']
#Y = dfB0007['capacity']
# Out:
#      cycle  capacity  max_discharge_temp  max_charge_temp
# 0        1  2.035338           39.162987        27.355870
# 1        2  2.025140           39.246203        31.874973
# 2        3  2.013326           38.999202        32.149173
# 3        4  2.013285           38.843628        32.017074
# 4        5  2.000528           38.977989        31.921070
# ..     ...       ...                 ...              ...
# 163    164  1.153818           41.149193        28.612333
# 164    165  1.164401           41.262683        28.542199
# 165    166  1.158797           41.457918        28.565426
# 166    167  1.174975           41.116662        28.631428
# 167    168  1.185675           41.362638        28.658802
#
# [168 rows x 4 columns]

# %%
dfB0007
print(dfB0007.columns)
print(dfB0007.shape)
# Out:
# Index(['cycle', 'capacity', 'max_discharge_temp', 'max_charge_temp'], dtype='object')
# (168, 4)

# %%
INPUT_DIMS = 4
TIME_STEPS = 10
lstm_units = 64

# %%
#Normalized
data,normalize = NormalizeMult(dfB0007)
capacity_data = data[:,0].reshape(len(dfB0007),1)
# Out:
# (4, 2)

# %%
train_X, _ = create_dataset(data,TIME_STEPS)
_ , train_Y = create_dataset(capacity_data,TIME_STEPS)

# %%
train_X.shape
# Out:
# (157, 10, 4)

# %%
train_Y.shape
# Out:
# (157, 1)

# %%
train_X, _ = create_dataset(data,TIME_STEPS)
_ , train_Y = create_dataset(capacity_data,TIME_STEPS)

print(train_X.shape,train_Y.shape)

m = attention_model()
m.summary()
m.compile(optimizer='adam', loss='mse')
m.fit([train_X], train_Y, epochs=100, batch_size=32, validation_split=0.2)
#m.save("./model.h5")
#np.save("normalize.npy",normalize)
# Out:
# (157, 10, 4) (157, 1)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10, 4)]      0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 10, 64)       320         input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 10, 64)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 10, 128)      66048       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 10, 128)      0           bidirectional[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10, 128)      16512       dropout_1[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 10, 128)      0           dense[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 10, 128)      0           dropout_1[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1280)         0           multiply[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            1281        flatten[0][0]
# ==================================================================================================
# Total params: 84,161
# Trainable params: 84,161
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 4/4 [==============================] - 5s 164ms/step - loss: 0.2300 - val_loss: 0.8017
# Epoch 2/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2228 - val_loss: 0.7853
# Epoch 3/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2140 - val_loss: 0.7626
# Epoch 4/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2011 - val_loss: 0.7265
# Epoch 5/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1806 - val_loss: 0.6656
# Epoch 6/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1499 - val_loss: 0.5705
# Epoch 7/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1101 - val_loss: 0.4496
# Epoch 8/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0699 - val_loss: 0.3227
# Epoch 9/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0466 - val_loss: 0.2116
# Epoch 10/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0446 - val_loss: 0.1505
# Epoch 11/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0531 - val_loss: 0.1510
# Epoch 12/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0474 - val_loss: 0.1749
# Epoch 13/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0441 - val_loss: 0.2063
# Epoch 14/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0430 - val_loss: 0.2271
# Epoch 15/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0405 - val_loss: 0.2296
# Epoch 16/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0412 - val_loss: 0.2190
# Epoch 17/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0395 - val_loss: 0.2008
# Epoch 18/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0374 - val_loss: 0.1839
# Epoch 19/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0343 - val_loss: 0.1745
# Epoch 20/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0324 - val_loss: 0.1627
# Epoch 21/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0295 - val_loss: 0.1509
# Epoch 22/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0265 - val_loss: 0.1404
# Epoch 23/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0216 - val_loss: 0.1294
# Epoch 24/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0168 - val_loss: 0.1109
# Epoch 25/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0096 - val_loss: 0.0780
# Epoch 26/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0056 - val_loss: 0.0542
# Epoch 27/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0058 - val_loss: 0.0443
# Epoch 28/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0050 - val_loss: 0.0366
# Epoch 29/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0063 - val_loss: 0.0361
# Epoch 30/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0053 - val_loss: 0.0459
# Epoch 31/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0047 - val_loss: 0.0386
# Epoch 32/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0041 - val_loss: 0.0435
# Epoch 33/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0046 - val_loss: 0.0471
# Epoch 34/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0040 - val_loss: 0.0426
# Epoch 35/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0036 - val_loss: 0.0411
# Epoch 36/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0034 - val_loss: 0.0411
# Epoch 37/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0036 - val_loss: 0.0415
# Epoch 38/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0040 - val_loss: 0.0370
# Epoch 39/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0039 - val_loss: 0.0412
# Epoch 40/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0028 - val_loss: 0.0407
# Epoch 41/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0027 - val_loss: 0.0350
# Epoch 42/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0032 - val_loss: 0.0381
# Epoch 43/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0029 - val_loss: 0.0405
# Epoch 44/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0033 - val_loss: 0.0376
# Epoch 45/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0023 - val_loss: 0.0368
# Epoch 46/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0025 - val_loss: 0.0360
# Epoch 47/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0024 - val_loss: 0.0427
# Epoch 48/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0024 - val_loss: 0.0376
# Epoch 49/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0020 - val_loss: 0.0337
# Epoch 50/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0020 - val_loss: 0.0350
# Epoch 51/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0018 - val_loss: 0.0355
# Epoch 52/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0021 - val_loss: 0.0346
# Epoch 53/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0021 - val_loss: 0.0364
# Epoch 54/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0015 - val_loss: 0.0343
# Epoch 55/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0018 - val_loss: 0.0295
# Epoch 56/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0016 - val_loss: 0.0339
# Epoch 57/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0022 - val_loss: 0.0331
# Epoch 58/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0020 - val_loss: 0.0284
# Epoch 59/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0017 - val_loss: 0.0320
# Epoch 60/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0018 - val_loss: 0.0296
# Epoch 61/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0018 - val_loss: 0.0279
# Epoch 62/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0019 - val_loss: 0.0324
# Epoch 63/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0014 - val_loss: 0.0302
# Epoch 64/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0013 - val_loss: 0.0293
# Epoch 65/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 0.0290
# Epoch 66/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 0.0298
# Epoch 67/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0019 - val_loss: 0.0284
# Epoch 68/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0022 - val_loss: 0.0307
# Epoch 69/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0013 - val_loss: 0.0308
# Epoch 70/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0017 - val_loss: 0.0286
# Epoch 71/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0013 - val_loss: 0.0305
# Epoch 72/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 0.0294
# Epoch 73/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0015 - val_loss: 0.0259
# Epoch 74/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 0.0284
# Epoch 75/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0015 - val_loss: 0.0288
# Epoch 76/100
# 4/4 [==============================] - 0s 21ms/step - loss: 9.7973e-04 - val_loss: 0.0248
# Epoch 77/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0014 - val_loss: 0.0255
# Epoch 78/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0017 - val_loss: 0.0281
# Epoch 79/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0010 - val_loss: 0.0244
# Epoch 80/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0016 - val_loss: 0.0255
# Epoch 81/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0011 - val_loss: 0.0250
# Epoch 82/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0013 - val_loss: 0.0219
# Epoch 83/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 0.0235
# Epoch 84/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 0.0253
# Epoch 85/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0017 - val_loss: 0.0211
# Epoch 86/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0014 - val_loss: 0.0207
# Epoch 87/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0013 - val_loss: 0.0238
# Epoch 88/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0014 - val_loss: 0.0221
# Epoch 89/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0011 - val_loss: 0.0205
# Epoch 90/100
# 4/4 [==============================] - 0s 23ms/step - loss: 8.4634e-04 - val_loss: 0.0225
# Epoch 91/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0010 - val_loss: 0.0213
# Epoch 92/100
# 4/4 [==============================] - 0s 21ms/step - loss: 8.4273e-04 - val_loss: 0.0202
# Epoch 93/100
# 4/4 [==============================] - 0s 23ms/step - loss: 8.6996e-04 - val_loss: 0.0195
# Epoch 94/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0010 - val_loss: 0.0191
# Epoch 95/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0013 - val_loss: 0.0212
# Epoch 96/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0012 - val_loss: 0.0195
# Epoch 97/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0011 - val_loss: 0.0189
# Epoch 98/100
# 4/4 [==============================] - 0s 25ms/step - loss: 7.6174e-04 - val_loss: 0.0187
# Epoch 99/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0012 - val_loss: 0.0202
# Epoch 100/100
# 4/4 [==============================] - 0s 23ms/step - loss: 8.7996e-04 - val_loss: 0.0175

# %%
from sklearn.model_selection import train_test_split
train_size = int(len(dfB0007)*0.8)
train = dfB0007.iloc[:train_size,:]
test = dfB0007.iloc[train_size:,:]
#train, test = train_test_split(df, test_size=0.1)
print("len(train):",len(train))
print("len(test):",len(test))
# Out:
# len(train): 134
# len(test): 34

# %%
import keras.backend as K
def r2_keras(y_true, y_pred):
    """Coefficient of Determination 
    """
    SS_res =  K.sum(K.square( y_true - y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
# %rm model.h5
# Out:
# rm: cannot remove 'model.h5': No such file or directory

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
model_path = './model.h5'
# TRAIN
INPUT_DIMS = 4
TIME_STEPS = 10
lstm_units = 64

#Normalized
train,normalize = NormalizeMult(train)
capacity_data = train[:,0].reshape(len(train),1)

train_X, _ = create_dataset(train,TIME_STEPS)
_ , train_Y = create_dataset(capacity_data,TIME_STEPS)
print(train_X.shape,train_Y.shape)

m = attention_model()
m.summary()
#m.compile(optimizer='adam', loss='mse')
m.compile(loss='mse', optimizer='adam',metrics=['mae',r2_keras])

# fit the network
history =  m.fit([train_X], train_Y, epochs=100, batch_size=32, validation_split=0.2)
#history = m.fit([train_X], train_Y, epochs=10, batch_size=64, validation_split=0.05, verbose=2,
#          callbacks = [EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min'),
#                       ModelCheckpoint(model_path,monitor='val_loss', save_best_only=True, mode='min', verbose=0)]
#          )
# Out:
# (4, 2)
# (123, 10, 4) (123, 1)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 10, 4)]      0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 10, 64)       320         input_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 10, 64)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 10, 128)      66048       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 10, 128)      0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10, 128)      16512       dropout_3[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 10, 128)      0           dense_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 10, 128)      0           dropout_3[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1280)         0           multiply_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            1281        flatten_1[0][0]
# ==================================================================================================
# Total params: 84,161
# Trainable params: 84,161
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 4/4 [==============================] - 5s 171ms/step - loss: 0.2366 - mae: 0.4375 - r2_keras: -330.8606 - val_loss: 0.7970 - val_mae: 0.8911 - val_r2_keras: -270.1305
# Epoch 2/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2290 - mae: 0.4290 - r2_keras: -5.1507 - val_loss: 0.7747 - val_mae: 0.8785 - val_r2_keras: -262.5176
# Epoch 3/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2191 - mae: 0.4180 - r2_keras: -6.5578 - val_loss: 0.7419 - val_mae: 0.8596 - val_r2_keras: -251.3680
# Epoch 4/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2056 - mae: 0.4022 - r2_keras: -6.0332 - val_loss: 0.6889 - val_mae: 0.8283 - val_r2_keras: -233.3560
# Epoch 5/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1830 - mae: 0.3752 - r2_keras: -2.9531 - val_loss: 0.6103 - val_mae: 0.7793 - val_r2_keras: -206.5904
# Epoch 6/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1503 - mae: 0.3316 - r2_keras: -2.4767 - val_loss: 0.5091 - val_mae: 0.7115 - val_r2_keras: -172.1958
# Epoch 7/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1075 - mae: 0.2749 - r2_keras: -8.3093 - val_loss: 0.3968 - val_mae: 0.6277 - val_r2_keras: -133.9929
# Epoch 8/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0710 - mae: 0.2211 - r2_keras: -1.6866 - val_loss: 0.2792 - val_mae: 0.5257 - val_r2_keras: -93.9737
# Epoch 9/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0456 - mae: 0.1806 - r2_keras: -0.1889 - val_loss: 0.1777 - val_mae: 0.4181 - val_r2_keras: -59.4527
# Epoch 10/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0408 - mae: 0.1695 - r2_keras: -0.5714 - val_loss: 0.1287 - val_mae: 0.3548 - val_r2_keras: -42.7874
# Epoch 11/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0486 - mae: 0.1825 - r2_keras: -1.5348 - val_loss: 0.1239 - val_mae: 0.3479 - val_r2_keras: -41.1377
# Epoch 12/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0473 - mae: 0.1791 - r2_keras: -0.3140 - val_loss: 0.1371 - val_mae: 0.3664 - val_r2_keras: -45.6245
# Epoch 13/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0394 - mae: 0.1685 - r2_keras: 0.0443 - val_loss: 0.1514 - val_mae: 0.3854 - val_r2_keras: -50.4886
# Epoch 14/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0378 - mae: 0.1616 - r2_keras: 0.1467 - val_loss: 0.1627 - val_mae: 0.3999 - val_r2_keras: -54.3601
# Epoch 15/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0387 - mae: 0.1679 - r2_keras: 0.1627 - val_loss: 0.1662 - val_mae: 0.4043 - val_r2_keras: -55.5524
# Epoch 16/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0375 - mae: 0.1647 - r2_keras: -0.4931 - val_loss: 0.1688 - val_mae: 0.4075 - val_r2_keras: -56.4215
# Epoch 17/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0327 - mae: 0.1527 - r2_keras: 0.1302 - val_loss: 0.1729 - val_mae: 0.4126 - val_r2_keras: -57.8256
# Epoch 18/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0343 - mae: 0.1554 - r2_keras: 0.1939 - val_loss: 0.1643 - val_mae: 0.4021 - val_r2_keras: -54.8999
# Epoch 19/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0295 - mae: 0.1459 - r2_keras: 0.3949 - val_loss: 0.1415 - val_mae: 0.3727 - val_r2_keras: -47.1448
# Epoch 20/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0264 - mae: 0.1328 - r2_keras: -0.0974 - val_loss: 0.1172 - val_mae: 0.3384 - val_r2_keras: -38.8519
# Epoch 21/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0253 - mae: 0.1332 - r2_keras: 0.2748 - val_loss: 0.0977 - val_mae: 0.3083 - val_r2_keras: -32.2208
# Epoch 22/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0206 - mae: 0.1151 - r2_keras: 0.4135 - val_loss: 0.0901 - val_mae: 0.2960 - val_r2_keras: -29.6641
# Epoch 23/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0155 - mae: 0.0954 - r2_keras: 0.6287 - val_loss: 0.0867 - val_mae: 0.2903 - val_r2_keras: -28.4943
# Epoch 24/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0113 - mae: 0.0858 - r2_keras: 0.7753 - val_loss: 0.0714 - val_mae: 0.2629 - val_r2_keras: -23.2950
# Epoch 25/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0080 - mae: 0.0769 - r2_keras: 0.8488 - val_loss: 0.0494 - val_mae: 0.2171 - val_r2_keras: -15.8076
# Epoch 26/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0043 - mae: 0.0561 - r2_keras: -0.7559 - val_loss: 0.0302 - val_mae: 0.1670 - val_r2_keras: -9.2664
# Epoch 27/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0040 - mae: 0.0535 - r2_keras: 0.2087 - val_loss: 0.0189 - val_mae: 0.1288 - val_r2_keras: -5.4207
# Epoch 28/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0058 - mae: 0.0650 - r2_keras: -2.4605 - val_loss: 0.0227 - val_mae: 0.1429 - val_r2_keras: -6.7215
# Epoch 29/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0047 - mae: 0.0564 - r2_keras: 0.9187 - val_loss: 0.0305 - val_mae: 0.1681 - val_r2_keras: -9.3844
# Epoch 30/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0044 - mae: 0.0563 - r2_keras: 0.8185 - val_loss: 0.0326 - val_mae: 0.1741 - val_r2_keras: -10.0872
# Epoch 31/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0039 - mae: 0.0511 - r2_keras: 0.5616 - val_loss: 0.0315 - val_mae: 0.1709 - val_r2_keras: -9.7118
# Epoch 32/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0038 - mae: 0.0486 - r2_keras: 0.6263 - val_loss: 0.0309 - val_mae: 0.1690 - val_r2_keras: -9.4982
# Epoch 33/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0032 - mae: 0.0457 - r2_keras: 0.8491 - val_loss: 0.0318 - val_mae: 0.1718 - val_r2_keras: -9.8112
# Epoch 34/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0038 - mae: 0.0496 - r2_keras: 0.8681 - val_loss: 0.0310 - val_mae: 0.1697 - val_r2_keras: -9.5560
# Epoch 35/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0032 - mae: 0.0438 - r2_keras: 0.6676 - val_loss: 0.0318 - val_mae: 0.1720 - val_r2_keras: -9.8151
# Epoch 36/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0026 - mae: 0.0409 - r2_keras: 0.9395 - val_loss: 0.0290 - val_mae: 0.1636 - val_r2_keras: -8.8612
# Epoch 37/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0019 - mae: 0.0356 - r2_keras: 0.9590 - val_loss: 0.0268 - val_mae: 0.1568 - val_r2_keras: -8.1190
# Epoch 38/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0021 - mae: 0.0357 - r2_keras: 0.9263 - val_loss: 0.0276 - val_mae: 0.1594 - val_r2_keras: -8.3783
# Epoch 39/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0028 - mae: 0.0415 - r2_keras: 0.9394 - val_loss: 0.0254 - val_mae: 0.1524 - val_r2_keras: -7.6346
# Epoch 40/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0021 - mae: 0.0359 - r2_keras: 0.9652 - val_loss: 0.0235 - val_mae: 0.1461 - val_r2_keras: -6.9857
# Epoch 41/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0022 - mae: 0.0373 - r2_keras: 0.9539 - val_loss: 0.0215 - val_mae: 0.1390 - val_r2_keras: -6.2985
# Epoch 42/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0026 - mae: 0.0376 - r2_keras: 0.6743 - val_loss: 0.0195 - val_mae: 0.1317 - val_r2_keras: -5.6344
# Epoch 43/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0024 - mae: 0.0363 - r2_keras: 0.8907 - val_loss: 0.0192 - val_mae: 0.1304 - val_r2_keras: -5.5164
# Epoch 44/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0023 - mae: 0.0377 - r2_keras: 0.9414 - val_loss: 0.0211 - val_mae: 0.1377 - val_r2_keras: -6.1701
# Epoch 45/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0020 - mae: 0.0330 - r2_keras: 0.9590 - val_loss: 0.0225 - val_mae: 0.1429 - val_r2_keras: -6.6514
# Epoch 46/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0017 - mae: 0.0303 - r2_keras: 0.9657 - val_loss: 0.0226 - val_mae: 0.1433 - val_r2_keras: -6.6823
# Epoch 47/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0018 - mae: 0.0322 - r2_keras: 0.9630 - val_loss: 0.0204 - val_mae: 0.1354 - val_r2_keras: -5.9486
# Epoch 48/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0015 - mae: 0.0306 - r2_keras: 0.9663 - val_loss: 0.0199 - val_mae: 0.1335 - val_r2_keras: -5.7681
# Epoch 49/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0015 - mae: 0.0281 - r2_keras: 0.9689 - val_loss: 0.0211 - val_mae: 0.1381 - val_r2_keras: -6.1838
# Epoch 50/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0012 - mae: 0.0255 - r2_keras: 0.8109 - val_loss: 0.0218 - val_mae: 0.1405 - val_r2_keras: -6.4074
# Epoch 51/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0019 - mae: 0.0332 - r2_keras: 0.9646 - val_loss: 0.0207 - val_mae: 0.1366 - val_r2_keras: -6.0429
# Epoch 52/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0015 - mae: 0.0309 - r2_keras: 0.9323 - val_loss: 0.0204 - val_mae: 0.1358 - val_r2_keras: -5.9565
# Epoch 53/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0015 - mae: 0.0287 - r2_keras: 0.9602 - val_loss: 0.0223 - val_mae: 0.1427 - val_r2_keras: -6.5819
# Epoch 54/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0014 - mae: 0.0265 - r2_keras: 0.9565 - val_loss: 0.0217 - val_mae: 0.1404 - val_r2_keras: -6.3652
# Epoch 55/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0013 - mae: 0.0281 - r2_keras: 0.9743 - val_loss: 0.0185 - val_mae: 0.1286 - val_r2_keras: -5.3027
# Epoch 56/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0013 - mae: 0.0276 - r2_keras: 0.9752 - val_loss: 0.0171 - val_mae: 0.1227 - val_r2_keras: -4.8111
# Epoch 57/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0014 - mae: 0.0274 - r2_keras: 0.9666 - val_loss: 0.0164 - val_mae: 0.1201 - val_r2_keras: -4.5869
# Epoch 58/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0014 - mae: 0.0271 - r2_keras: 0.8425 - val_loss: 0.0168 - val_mae: 0.1216 - val_r2_keras: -4.7080
# Epoch 59/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0012 - mae: 0.0246 - r2_keras: 0.9782 - val_loss: 0.0178 - val_mae: 0.1257 - val_r2_keras: -5.0455
# Epoch 60/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0012 - mae: 0.0268 - r2_keras: 0.9540 - val_loss: 0.0195 - val_mae: 0.1326 - val_r2_keras: -5.6421
# Epoch 61/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0017 - mae: 0.0282 - r2_keras: 0.9422 - val_loss: 0.0213 - val_mae: 0.1393 - val_r2_keras: -6.2515
# Epoch 62/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0016 - mae: 0.0286 - r2_keras: 0.9610 - val_loss: 0.0203 - val_mae: 0.1354 - val_r2_keras: -5.8956
# Epoch 63/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0013 - mae: 0.0272 - r2_keras: 0.9723 - val_loss: 0.0201 - val_mae: 0.1349 - val_r2_keras: -5.8532
# Epoch 64/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0011 - mae: 0.0242 - r2_keras: 0.9608 - val_loss: 0.0204 - val_mae: 0.1358 - val_r2_keras: -5.9357
# Epoch 65/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0011 - mae: 0.0250 - r2_keras: 0.9786 - val_loss: 0.0174 - val_mae: 0.1241 - val_r2_keras: -4.9235
# Epoch 66/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0013 - mae: 0.0272 - r2_keras: 0.8339 - val_loss: 0.0185 - val_mae: 0.1285 - val_r2_keras: -5.2918
# Epoch 67/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0012 - mae: 0.0263 - r2_keras: -8.7389 - val_loss: 0.0215 - val_mae: 0.1401 - val_r2_keras: -6.3264
# Epoch 68/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0011 - mae: 0.0252 - r2_keras: 0.9790 - val_loss: 0.0179 - val_mae: 0.1261 - val_r2_keras: -5.0777
# Epoch 69/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0011 - mae: 0.0245 - r2_keras: 0.9614 - val_loss: 0.0161 - val_mae: 0.1187 - val_r2_keras: -4.4729
# Epoch 70/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0011 - mae: 0.0247 - r2_keras: 0.9668 - val_loss: 0.0173 - val_mae: 0.1238 - val_r2_keras: -4.8769
# Epoch 71/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0013 - mae: 0.0259 - r2_keras: 0.9758 - val_loss: 0.0167 - val_mae: 0.1215 - val_r2_keras: -4.6915
# Epoch 72/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0010 - mae: 0.0236 - r2_keras: 0.9797 - val_loss: 0.0152 - val_mae: 0.1152 - val_r2_keras: -4.1836
# Epoch 73/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0013 - mae: 0.0269 - r2_keras: -0.3578 - val_loss: 0.0168 - val_mae: 0.1217 - val_r2_keras: -4.7024
# Epoch 74/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0016 - mae: 0.0280 - r2_keras: 0.9378 - val_loss: 0.0227 - val_mae: 0.1443 - val_r2_keras: -6.7089
# Epoch 75/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0018 - mae: 0.0305 - r2_keras: 0.9673 - val_loss: 0.0205 - val_mae: 0.1365 - val_r2_keras: -5.9805
# Epoch 76/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0010 - mae: 0.0245 - r2_keras: 0.9712 - val_loss: 0.0173 - val_mae: 0.1237 - val_r2_keras: -4.8684
# Epoch 77/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0011 - mae: 0.0244 - r2_keras: 0.9587 - val_loss: 0.0152 - val_mae: 0.1152 - val_r2_keras: -4.1822
# Epoch 78/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0012 - mae: 0.0266 - r2_keras: 0.1005 - val_loss: 0.0152 - val_mae: 0.1152 - val_r2_keras: -4.1788
# Epoch 79/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0011 - mae: 0.0245 - r2_keras: 0.9796 - val_loss: 0.0170 - val_mae: 0.1226 - val_r2_keras: -4.7703
# Epoch 80/100
# 4/4 [==============================] - 0s 21ms/step - loss: 9.0908e-04 - mae: 0.0220 - r2_keras: 0.7447 - val_loss: 0.0182 - val_mae: 0.1277 - val_r2_keras: -5.1951
# Epoch 81/100
# 4/4 [==============================] - 0s 24ms/step - loss: 9.8686e-04 - mae: 0.0243 - r2_keras: 0.9792 - val_loss: 0.0189 - val_mae: 0.1303 - val_r2_keras: -5.4174
# Epoch 82/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0013 - mae: 0.0272 - r2_keras: 0.9509 - val_loss: 0.0180 - val_mae: 0.1269 - val_r2_keras: -5.1296
# Epoch 83/100
# 4/4 [==============================] - 0s 22ms/step - loss: 8.7660e-04 - mae: 0.0227 - r2_keras: 0.9767 - val_loss: 0.0159 - val_mae: 0.1183 - val_r2_keras: -4.4174
# Epoch 84/100
# 4/4 [==============================] - 0s 22ms/step - loss: 8.7774e-04 - mae: 0.0234 - r2_keras: 0.6955 - val_loss: 0.0168 - val_mae: 0.1220 - val_r2_keras: -4.7007
# Epoch 85/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0011 - mae: 0.0255 - r2_keras: 0.6715 - val_loss: 0.0177 - val_mae: 0.1259 - val_r2_keras: -5.0204
# Epoch 86/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0014 - mae: 0.0296 - r2_keras: 0.9670 - val_loss: 0.0148 - val_mae: 0.1132 - val_r2_keras: -4.0179
# Epoch 87/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0013 - mae: 0.0280 - r2_keras: -4.7771 - val_loss: 0.0141 - val_mae: 0.1101 - val_r2_keras: -3.7889
# Epoch 88/100
# 4/4 [==============================] - 0s 22ms/step - loss: 8.5862e-04 - mae: 0.0229 - r2_keras: 0.8805 - val_loss: 0.0164 - val_mae: 0.1207 - val_r2_keras: -4.5949
# Epoch 89/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0011 - mae: 0.0244 - r2_keras: 0.9751 - val_loss: 0.0155 - val_mae: 0.1165 - val_r2_keras: -4.2563
# Epoch 90/100
# 4/4 [==============================] - 0s 21ms/step - loss: 7.9072e-04 - mae: 0.0224 - r2_keras: 0.9842 - val_loss: 0.0134 - val_mae: 0.1071 - val_r2_keras: -3.5632
# Epoch 91/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0010 - mae: 0.0236 - r2_keras: 0.9764 - val_loss: 0.0133 - val_mae: 0.1065 - val_r2_keras: -3.5208
# Epoch 92/100
# 4/4 [==============================] - 0s 22ms/step - loss: 6.5530e-04 - mae: 0.0204 - r2_keras: 0.9754 - val_loss: 0.0144 - val_mae: 0.1116 - val_r2_keras: -3.8844
# Epoch 93/100
# 4/4 [==============================] - 0s 23ms/step - loss: 9.3287e-04 - mae: 0.0240 - r2_keras: 0.9547 - val_loss: 0.0175 - val_mae: 0.1253 - val_r2_keras: -4.9493
# Epoch 94/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0012 - mae: 0.0237 - r2_keras: 0.9766 - val_loss: 0.0173 - val_mae: 0.1246 - val_r2_keras: -4.8944
# Epoch 95/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0014 - mae: 0.0263 - r2_keras: 0.9701 - val_loss: 0.0146 - val_mae: 0.1127 - val_r2_keras: -3.9621
# Epoch 96/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0011 - mae: 0.0247 - r2_keras: 0.7616 - val_loss: 0.0122 - val_mae: 0.1015 - val_r2_keras: -3.1645
# Epoch 97/100
# 4/4 [==============================] - 0s 24ms/step - loss: 9.8065e-04 - mae: 0.0239 - r2_keras: -16.2309 - val_loss: 0.0107 - val_mae: 0.0937 - val_r2_keras: -2.6567
# Epoch 98/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0013 - mae: 0.0273 - r2_keras: 0.9728 - val_loss: 0.0129 - val_mae: 0.1047 - val_r2_keras: -3.3730
# Epoch 99/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0013 - mae: 0.0305 - r2_keras: 0.9706 - val_loss: 0.0151 - val_mae: 0.1150 - val_r2_keras: -4.1347
# Epoch 100/100
# 4/4 [==============================] - 0s 23ms/step - loss: 9.8269e-04 - mae: 0.0251 - r2_keras: 0.9054 - val_loss: 0.0141 - val_mae: 0.1102 - val_r2_keras: -3.7819

# %%
import matplotlib.pyplot as plt

# summarize history for R^2
#fig_acc = plt.figure(figsize=(10, 10))
#plt.plot(history.history['r2_keras'])
#plt.plot(history.history['val_r2_keras'])
#plt.title('model r^2')
#plt.ylabel('R^2')
#plt.xlabel('epoch')
#plt.legend(['train', 'validation'], loc='upper left')
#plt.show()

# summarize history for MAE
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('model MAE')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# summarize history for Loss
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# TEST
test,normalize = NormalizeMult(test)
capacity_test = test[:,0].reshape(len(test),1)

test_X, _ = create_dataset(test,TIME_STEPS)
_ , test_Y = create_dataset(capacity_test,TIME_STEPS)
print(test_X.shape,test_Y.shape)
# Out:
# (4, 2)
# (23, 10, 4) (23, 1)

# %%
scores_test = m.evaluate([test_X], test_Y, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.0240 - mae: 0.1287 - r2_keras: 0.4052

# %%
scores_test
# Out:
# [0.024031419306993484, 0.1287410706281662, 0.40522247552871704]

# %%
results = m.predict([test_X])
results
# Out:
# array([[0.28396305],
#        [0.31514126],
#        [0.34219107],
#        [0.36849758],
#        [0.39884624],
#        [0.41875497],
#        [0.43517858],
#        [0.44988433],
#        [0.47656718],
#        [0.4846484 ],
#        [0.49683622],
#        [0.5066672 ],
#        [0.53081906],
#        [0.55087644],
#        [0.5551534 ],
#        [0.5627826 ],
#        [0.57678187],
#        [0.6068031 ],
#        [0.6187724 ],
#        [0.64436126],
#        [0.6643049 ],
#        [0.6881354 ],
#        [0.6993535 ]], dtype=float32)

# %%
test_Y
# Out:
# array([[0.3030303 ],
#        [0.33333333],
#        [0.36363636],
#        [0.39393939],
#        [0.42424242],
#        [0.45454545],
#        [0.48484848],
#        [0.51515152],
#        [0.54545455],
#        [0.57575758],
#        [0.60606061],
#        [0.63636364],
#        [0.66666667],
#        [0.6969697 ],
#        [0.72727273],
#        [0.75757576],
#        [0.78787879],
#        [0.81818182],
#        [0.84848485],
#        [0.87878788],
#        [0.90909091],
#        [0.93939394],
#        [0.96969697]])

# %%
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(results[:100])
plt.plot(test_Y[:100])
plt.title('real vs pred')
plt.ylabel('value')
plt.xlabel('epoch')
plt.legend(['pred', 'real'], loc='upper left')
plt.show()
